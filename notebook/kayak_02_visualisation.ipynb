# %% [markdown]
# # Bloc 01 - Plan your trip with Kayak

# %% [markdown]
# ## 02 - Visualisation

# %% [markdown]
# Import de librairies

# %%
import pandas as pd
import plotly.express as px
from dotenv import load_dotenv
from IPython.display import Image

load_dotenv()
# Out:
# True

# %%
df_hotels = pd.read_csv("../data/scrap_booking.csv")

# %%
data_hotels = df_hotels.copy()
data_hotels.head()
# Out:
#                 city        lat       lon  \
# 0  Mont Saint Michel  48.577087 -1.562743
# 1  Mont Saint Michel  48.713811 -1.489071
# 2  Mont Saint Michel  48.714573 -1.485254
# 3  Mont Saint Michel  48.631960 -1.389475
# 4  Mont Saint Michel  48.555020 -1.512412
#
#                                          name  \
# 0                              A place of zen
# 1                                 Petit Bijou
# 2                    Le Domaine de Belleville
# 3                                 Rue Veillon
# 4  L'Orée du Mont proche du mont saint Michel
#
#                                                  url  review_score  \
# 0  https://www.booking.com/hotel/fr/a-place-of-ze...           9.9
# 1  https://www.booking.com/hotel/fr/petit-bijou-d...           9.7
# 2  https://www.booking.com/hotel/fr/le-domaine-de...           9.7
# 3  https://www.booking.com/hotel/fr/rue-veillon.f...           9.9
# 4  https://www.booking.com/hotel/fr/oree-du-mont....           9.7
#
#                                                 desc
# 0  Situé à Saint-Georges-de-Gréhaigne, l’hébergem...
# 1  Offrant une vue sur le jardin, l’hébergement P...
# 2  Offrant une vue sur le jardin, l’établissement...
# 3  L’hébergement Rue Veillon vous accueille à res...
# 4  L’établissement L'Orée du Mont proche du mont ...

# %%
all_villes_score = pd.read_csv("../data/cities.csv")

# %% [markdown]
# ## Cartes

# %%
top5_villes = all_villes_score[:5]
print(top5_villes)

top20_hotels = data_hotels[data_hotels["city"].isin(top5_villes["city"])]
print(top20_hotels)
# Out:
#          city      lat     lon  city_score  score_normalized
# 0  Strasbourg  48.5846  7.7507    2.428571           1.00000
# 1    Le Havre  49.4939  0.1080    1.857143           0.87500
# 2       Lille  50.6366  3.0635    1.857143           0.87500
# 3       Paris  48.8535  2.3484    1.857143           0.87500
# 4      Amiens  49.8942  2.2957    1.714286           0.84375
#          city        lat       lon  \
# 46   Le Havre  49.495990  0.152054
# 48   Le Havre  49.496836  0.106893
# 49   Le Havre  49.489465  0.104953
# 51   Le Havre  49.496965  0.117475
# 52   Le Havre  49.487037  0.113150
# ..        ...        ...       ...
# 680     Paris  48.859033  2.376734
# 681     Paris  48.853485  2.336409
# 682     Paris  48.886224  2.335281
# 683     Paris  48.853843  2.294213
# 687  Le Havre  49.499490  0.106418
#
#                                                   name  \
# 46                          Petite maison indépendante
# 48   LA PARENTHÈSE HAVRAISE - Parking privé Plein c...
# 49                     Charmant T2 52m2 en Hypercentre
# 51   Cocon d'Evasion**** SPA PRIVATIF et ciels étoilés
# 52              L'Armateur - Confort - Standing Marché
# ..                                                 ...
# 680       Paris my home, GF, AIR COND, 2 SHOWERS, 2 WC
# 681                                     Villa-des-Prés
# 682                          Hôtel des Arts Montmartre
# 683        Relais12bis Bed & Breakfast By Eiffel Tower
# 687                        Les chambres du Chat Perché
#
#                                                    url  review_score  \
# 46   https://www.booking.com/hotel/fr/petite-maison...           9.2
# 48   https://www.booking.com/hotel/fr/la-parenthese...           9.1
# 49   https://www.booking.com/hotel/fr/charmant-t2-e...           9.3
# 51   https://www.booking.com/hotel/fr/cocon-d-evasi...           9.3
# 52   https://www.booking.com/hotel/fr/armateur-conf...           9.3
# ..                                                 ...           ...
# 680  https://www.booking.com/hotel/fr/gorgeous-desi...           9.8
# 681  https://www.booking.com/hotel/fr/villa-des-pre...           9.6
# 682  https://www.booking.com/hotel/fr/hoteldesarts....           9.6
# 683  https://www.booking.com/hotel/fr/relais-12-bis...           9.6
# 687  https://www.booking.com/hotel/fr/les-chambres-...           9.6
#
#                                                   desc
# 46   L’hébergement Petite maison indépendante propo...
# 48   L’hébergement 3 étoiles LA PARENTHÈSE HAVRAISE...
# 49   L’hébergement Charmant T2 52m2 en Hypercentre ...
# 51   Proposant une terrasse, l’hébergement Cocon d'...
# 52   L’hébergement L'Armateur - Confort - Standing ...
# ..                                                 ...
# 680  L’hébergement Paris my home, GF, AIR COND, 2 S...
# 681  L’établissement Villa-des-Prés vous accueille ...
# 682  L’Hôtel des Arts Montmartre est situé dans le ...
# 683  Situé à Paris, à 500 mètres de la Tour Eiffel,...
# 687  L’établissement Les chambres du Chat Perché se...
#
# [100 rows x 7 columns]

# %%
def show_graph(fig, filename="map.png"):
    
    fig.write_image(filename)

    try:
        from IPython import get_ipython
        if get_ipython() is not None:
            fig.show()
        else:
            display(Image(filename))
    except:
        display(Image(filename))

# %%
top5_villes_map = px.scatter_geo(
    top5_villes,
    lat="lat",
    lon="lon",
    hover_name="city",
    size="score_normalized",
    color="score_normalized",
    color_continuous_scale="thermal",
    projection="mercator",
    scope="europe",
    title="Top 5 des villes à visiter",
    size_max=40,
    labels={"score_normalized": "Score"},
    width=1000,
    height=800,
)

top5_villes_map.update_layout(
    geo=dict(
        center=dict(lat=46.5, lon=2.5),  # centre approximatif sur la France
        lataxis=dict(range=[41, 51]),    # limites latitude
        lonaxis=dict(range=[-5, 10])     # limites longitude
    )
)

top5_villes_map.show()

top5_villes_filename = "../images/top5_villes_map.png"
top5_villes_map.write_image(top5_villes_filename)
display(Image(top5_villes_filename))

# %%
top20_hotels_map = px.scatter_geo(
    top20_hotels,
    lat="lat",
    lon="lon",
    hover_name="name",
    hover_data=["city", "lat", "lon", "review_score"],
    color="city",
    color_continuous_scale="thermal",
    projection="mercator",
    scope="europe",
    title="Top 20 des hotels par ville",
    # size_max=40,
    labels={"city": "Ville"},
    width=1000,
    height=800,
)

top20_hotels_map.update_layout(
    geo=dict(
        center=dict(lat=46.5, lon=2.5),  # centre approximatif sur la France
        lataxis=dict(range=[41, 51]),    # limites latitude
        lonaxis=dict(range=[-5, 10])     # limites longitude
    )
)

top20_hotels_map.show()

top20_hotels_filename = "../images/top20_hotels_map.png"
top20_hotels_map.write_image(top20_hotels_filename)
display(Image(top20_hotels_filename))
