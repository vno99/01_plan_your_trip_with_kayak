# %% [markdown]
# # Bloc 01 - Plan your trip with Kayak

# %% [markdown]
# ## 03 - Datalake

# %% [markdown]
# Import de librairies

# %%
import os

import boto3
from dotenv import load_dotenv
from IPython.display import Image

load_dotenv()
# Out:
# True

# %%
# Variables d'environnement
AWS_ACCESS_KEY_ID = os.environ["AWS_ACCESS_KEY_ID"]
AWS_SECRET_ACCESS_KEY = os.environ["AWS_SECRET_ACCESS_KEY"]

bucket_name = os.environ["BUCKET_NAME"]

s3 = boto3.client(
    "s3",
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    region_name="eu-west-3"
)

# %%
s3.upload_file("../data/openweathermap_data.csv", bucket_name, "openweathermap_data.csv")
s3.upload_file("../data/scrap_booking.csv", bucket_name, "scrap_booking.csv")
s3.upload_file("../data/cities.csv", bucket_name, "cities.csv")

# %%
display(Image(filename="../images/datalake.png"))
